# %% [markdown]
# # Air Travel to Southern California

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Background

# %% [markdown]
# In 2017, 48.5 million tourists traveled to California and that number continues to grow annually[1]. This is due to the nice, warm weather year round, the many attractions and beaches, and the exploding corporate industries. Whether one is traveling for business or leisure, the many attractions across Southern California are extremely accessible to visitors by the numerous airports across the region.

# %% [markdown]
# ### 1.2 Problem

# %% [markdown]
# Although the plethora of airports in Southern California make traveling there easier, choosing the right airport for one’s specific needs can be a frustrating and daunting task. This project aims to simplify the process and help the traveler(s) choose the best airport so that they can focus more on enjoying themselves.

# %% [markdown]
# ### 1.3 Interest

# %% [markdown]
# Those interested in this report are air travelers heading to Southern California for either business or leisure.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# In order to find a solution to our problem, we need to know the location of the airports in Southern California and  a list of the top attractions in the region.
# For this project, I will use the Foursquare API to locate the airports across Southern California as well as determine and find the most popular attractions so that visitors will know which airport to fly into depending on their itineraries. I will then populate a hypothetical dataframe with this information and use a segmentation and clustering algorithmto determine which airport to fly into depending on the attraction you plan on visiting(assuming you will be staying in close vicinity of that attraction).

# %% [markdown]
# ### 2.1 Locating and Mapping Airports

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
#create dataframe
airport_data = [('LAX', 'Los Angeles', '34.0522', '-118.2437'),('BUR', 'Burbank', '34.1983', '-118.3574'),('SNA', 'Santa Ana', '33.675556', '-117.868333'),('LGB', 'Long Beach', '33.817778','-118.151667'),('ONT', 'Ontario', '34.056111',' -118.151667-117.601111'),('SAN', 'San Diego', '32.733611','-117.189722')]
labels = ['airport_code','city','latitude','longitude']
df_airports = pd.DataFrame.from_records(airport_data, columns = labels)
df_airports

# %% [markdown]
# ### 2.2 Locating Popular Southern California Attractions

# %%
#Use Foursquare API to obtain venues
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')

# %%
CLIENT_ID = 'BRGR1LFW5FO5FXFV3UGTK10RLPUL03M4ND5NQ0E5ZVVPLH04' # your Foursquare ID
CLIENT_SECRET = '5WPK0YWJOWN4TVQRGTP44SRIRCRKUPUZEXKNUU4KEV4F3GQB' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentials')
      
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
#Searching for attractions near LAX
address = '1 World Way, Los Angeles, CA 90045'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

search_query = 'Hilton Hotels'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_LAX = json_normalize(venues)
df_LAX.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1                                                 []    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
#
#                          id          location.address location.cc  \
# 0  4aaed4b0f964a520786320e3               1707 4th St          US
# 1  4c9638c301dd76b08592c148      9336 Civic Center Dr          US
# 2  4b234130f964a520b25424e3  2800 Via Cabrillo Marina          US
# 3  4b1b5060f964a520c3fa23e3       5711 W Century Blvd          US
# 4  52ea6af4498e29d798d144a2                       NaN          US
#
#   location.city location.country location.crossStreet  location.distance  \
# 0  Santa Monica    United States                  NaN              11167
# 1   California,    United States       Beverly Hills,              14585
# 2     San Pedro    United States                  NaN              27435
# 3   Los Angeles    United States     at Aviation Blvd               1554
# 4   Los Angeles    United States                  NaN               1540
#
#                            location.formattedAddress  \
# 0  [1707 4th St, Santa Monica, CA 90401, United S...
# 1  [9336 Civic Center Dr (Beverly Hills,), Califo...
# 2  [2800 Via Cabrillo Marina, San Pedro, CA 90731...
# 3  [5711 W Century Blvd (at Aviation Blvd), Los A...
# 4             [Los Angeles, CA 90045, United States]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 34.0117436, 'lng'...     34.011744
# 1  [{'label': 'display', 'lat': 34.07628764404890...     34.076288
# 2  [{'label': 'display', 'lat': 33.718573, 'lng':...     33.718573
# 3  [{'label': 'display', 'lat': 33.9461767, 'lng'...     33.946177
# 4  [{'label': 'display', 'lat': 33.94614991344601...     33.946150
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0   -118.489113                   NaN               90401             CA
# 1   -118.392676                   NaN               90210             CA
# 2   -118.282252                   NaN               90731             CA
# 3   -118.381616      West Los Angeles               90045             CA
# 4   -118.381765                   NaN               90045             CA
#
#                                                 name    referralId  \
# 0     DoubleTree Suites by Hilton Hotel Santa Monica  v-1568526784
# 1                                 Hilton Hotels Corp  v-1568526784
# 2  DoubleTree by Hilton Hotel San Pedro - Port of...  v-1568526784
# 3                         Hilton Los Angeles Airport  v-1568526784
# 4     Hilton Los Angeles Airport Hotel Health Center  v-1568526784
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
df_LAX_filtered = df_LAX.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_LAX_filtered['categories'] = df_LAX_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_LAX_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
df_LAX_filtered

# %%
#subset of dataframe
df1_LAX = df_LAX_filtered[['name','city', 'distance','lat','lng']]
df1_LAX

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around LAX

# add a red circle marker to represent LAX
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Hilton Hotels as blue circle markers
for lat, lng, label in zip(df_LAX_filtered.lat, df_LAX_filtered.lng, df_LAX_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-24efb6699660> in <module>
#      13
#      14 # add the Hilton Hotels as blue circle markers
# ---> 15 for lat, lng, label in zip(df_LAX_filtered.lat, df_LAX_filtered.lng, df_LAX_filtered.categories):
#      16     folium.features.CircleMarker(
#      17         [lat, lng],
#
# NameError: name 'df_LAX_filtered' is not defined

# %%
#Searching for attractions near BUR
address = '2627 N Hollywood Wy, Burbank, CA 91505'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
search_query = 'Hilton Hotels'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_BUR = json_normalize(venues)
df_BUR.head()
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_BUR.columns if col.startswith('location.')] + ['id']
df_BUR_filtered = df_BUR.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_BUR_filtered['categories'] = df_BUR_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_BUR_filtered.columns = [column.split('.')[-1] for column in df_BUR_filtered.columns]
#subset of dataframe
df1_BUR = df_BUR_filtered[['name','city', 'distance','lat','lng']]
df1_BUR
# Out:
# 34.1674848 -118.3468132
# Hilton Hotels .... OK!
#                                                  name            city  \
# 0      DoubleTree Suites by Hilton Hotel Santa Monica    Santa Monica
# 1                                  Hilton Hotels Corp     California,
# 2   DoubleTree by Hilton Hotel San Pedro - Port of...       San Pedro
# 3                   Hilton Los Angeles/Universal City  Universal City
# 4   Hilton Los Angeles North/Glendale & Executive ...        Glendale
# 5   DoubleTree by Hilton Hotel Santa Ana - Orange ...       Santa Ana
# 6             Hilton Garden Inn Los Angeles/Hollywood     Los Angeles
# 7                               Hilton Fitness Center  Universal City
# 8                  Hilton Garden Inn Burbank Downtown         Burbank
# 9                                  The Beverly Hilton   Beverly Hills
# 10                         Hilton Los Angeles Airport     Los Angeles
# 11                        Hilton Checkers Los Angeles     Los Angeles
# 12                              Hilton Inn Garden GYM     Los Angeles
# 13                                        Hilton Pool        Glendale
# 14                              Hilton Fitness Center        Glendale
# 15          DoubleTree by Hilton Los Angeles Downtown     Los Angeles
# 16                                    Hilton Pasadena        Pasadena
# 17                                       D Pet Hotels     Los Angeles
# 18     Hilton Los Angeles Airport Hotel Health Center     Los Angeles
# 19                                  Hilton Garden Inn  Marina del Rey
# 20                     Hilton Los Angeles/San Gabriel     San Gabriel
# 21      International Ballroom - Beverly Hilton Hotel   Beverly Hills
# 22                  Hilton Woodland Hills/Los Angeles  Woodland Hills
# 23                   Hilton Los Angeles Airport  Pool     Los Angeles
# 24  DoubleTree by Hilton Hotel Los Angeles - Westside     Culver City
# 25                          Hilton Checkers Roof Deck     Los Angeles
# 26                      Poolside @ The Beverly Hilton   Beverly Hills
# 27                                  Hilton Garden Inn      Montebello
# 28   Hotel MdR Marina del Rey- a DoubleTree by Hilton  Marina del Rey
# 29       Stardust Rooftop At The Beverly Hilton Hotel   Beverly Hills
# 30                  Beverly Hilton (Buffet Breakfast)     Los Angeles
# 31                      Beverly Hilton Fitness Center   Beverly Hills
# 32                           D Pet Hotels Los Angeles          Encino
# 33                        Hilton LAX Executive Lounge      El Segundo
# 34                       Hilton Auto Collision Center        Pasadena
# 35                      Hilton Pasdena Fitness Center        Pasadena
# 36                                  Hilton Garden Inn      El Segundo
# 37  Embassy Suites by Hilton Los Angeles Internati...      El Segundo
# 38  Embassy Suites by Hilton Los Angeles Internati...     Los Angeles
# 39        Hilton Garden Inn Los Angeles/Redondo Beach   Redondo Beach
# 40                                  Hilton Garden Inn       Calabasas
# 41                                 Hilton LAX Shuttle     Los Angeles
# 42                                  Hilton Garden Inn         Arcadia
# 43                         DoubleTree by Hilton Hotel        Commerce
# 44  DoubleTree by Hilton Hotel Los Angeles - Rosemead        Rosemead
# 45        DoubleTree by Hilton Hotel LAX - El Segundo      El Segundo
# 46    H Hotel Los Angeles, Curio Collection by Hilton     Los Angeles
# 47                             Dr. Dan P. Hilton, DDS  Woodland Hills
# 48                                  Hilton Garden Inn   Redondo Beach
# 49            Hilton Garden Inn Arcadia/Pasadena Area         Arcadia
#
#     distance        lat         lng
# 0      21740  34.011744 -118.489113
# 1      10996  34.076288 -118.392676
# 2      50326  33.718573 -118.282252
# 3       3602  34.136646 -118.358679
# 4       8373  34.158749 -118.256519
# 5      68363  33.700441 -117.866176
# 6       6824  34.106633 -118.337792
# 7       3615  34.136373 -118.358065
# 8       3966  34.178007 -118.305662
# 9      12783  34.066407 -118.412652
# 10     24843  33.946177 -118.381616
# 11     15613  34.049615 -118.254996
# 12      6968  34.105432 -118.336849
# 13      8352  34.158831 -118.256742
# 14      8366  34.158680 -118.256605
# 15     16185  34.050352 -118.242768
# 16     19186  34.142789 -118.140677
# 17      8643  34.090130 -118.338661
# 18     24848  33.946150 -118.381765
# 19     22857  33.983874 -118.457787
# 20     24578  34.079801 -118.102036
# 21     12830  34.066028 -118.412879
# 22     23087  34.186164 -118.596486
# 23     24868  33.945976 -118.381824
# 24     21077  33.982665 -118.396482
# 25     15575  34.050292 -118.254498
# 26     12848  34.065847 -118.412879
# 27     25082  34.027291 -118.133803
# 28     22086  33.985062 -118.441014
# 29     12800  34.066169 -118.412502
# 30     12838  34.066003 -118.412994
# 31     12789  34.066504 -118.413011
# 32     15598  34.162424 -118.516058
# 33     24859  33.946056 -118.381801
# 34     21054  34.149558 -118.119269
# 35     19117  34.142117 -118.141560
# 36     27500  33.922843 -118.388279
# 37     26843  33.930516 -118.400708
# 38     24818  33.946967 -118.386438
# 39     30511  33.893885 -118.366628
# 40     27858  34.151491 -118.648628
# 41     24957  33.945593 -118.385550
# 42     29704  34.141711 -118.025867
# 43     25683  34.003756 -118.150533
# 44     28517  34.037180 -118.080440
# 45     27884  33.919781 -118.391767
# 46     24994  33.946193 -118.392698
# 47     22417  34.167097 -118.590207
# 48     30529  33.893724 -118.366556
# 49     29707  34.141850 -118.025817

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around BUR

# add a red circle marker to represent BUR
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Hilton Hotels as blue circle markers
for lat, lng, label in zip(df_BUR_filtered.lat, df_BUR_filtered.lng, df_BUR_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Searching for attractions near SNA
address = '18601 Airport Way, Santa Ana, CA 92707'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

search_query = 'Hilton Hotels'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_SNA = json_normalize(venues)
df_SNA.head()
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_SNA.columns if col.startswith('location.')] + ['id']
df_SNA_filtered = df_SNA.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_SNA_filtered['categories'] = df_SNA_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_SNA_filtered.columns = [column.split('.')[-1] for column in df_SNA_filtered.columns]
#subset of dataframe
df1_SNA = df_SNA_filtered[['name','city', 'distance','lat','lng']]
df1_SNA
# Out:
# 33.682329 -117.859163
# Hilton Hotels .... OK!
#                                                 name          city  distance  \
# 0  DoubleTree by Hilton Hotel Santa Ana - Orange ...     Santa Ana      2118
# 1     DoubleTree Suites by Hilton Hotel Santa Monica  Santa Monica     68823
# 2  DoubleTree by Hilton Hotel San Pedro - Port of...     San Pedro     39390
# 3                Hilton Irvine/Orange County Airport        Irvine       853
# 4                                 Hilton Hotels Corp   California,     65987
# 5                                  Hilton Garden Inn        Irvine       997
# 6                     Hilton Hotel- Monarch Ballroom        Irvine       842
# 7                    Hilton Orange County/Costa Mesa    Costa Mesa      2337
# 8                    Hilton Hotel - Crystal Ballroom        Irvine       846
# 9                                     Hilton Anaheim       Anaheim     14271
#
#          lat         lng
# 0  33.700441 -117.866176
# 1  34.011744 -118.489113
# 2  33.718573 -118.282252
# 3  33.674785 -117.860783
# 4  34.076288 -118.392676
# 5  33.680504 -117.848625
# 6  33.674906 -117.860910
# 7  33.683279 -117.884372
# 8  33.674840 -117.860725
# 9  33.800684 -117.918432

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around SNA

# add a red circle marker to represent SNA
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Hilton Hotels as blue circle markers
for lat, lng, label in zip(df_SNA_filtered.lat, df_SNA_filtered.lng, df_SNA_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c7cd20b52bcc> in <module>
#      13
#      14 # add the Hilton Hotels as blue circle markers
# ---> 15 for lat, lng, label in zip(df_SNA_filtered.lat, df_SNA_filtered.lng, df_SNA_filtered.categories):
#      16     folium.features.CircleMarker(
#      17         [lat, lng],
#
# NameError: name 'df_SNA_filtered' is not defined

# %%
#Searching for attractions near LGB
address = '4100 Donald Douglas Dr. Long Beach, CA 90808'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

search_query = 'Hilton Hotels'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_LGB = json_normalize(venues)
df_LGB.head()
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_LGB.columns if col.startswith('location.')] + ['id']
df_LGB_filtered = df_LGB.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_LGB_filtered['categories'] = df_LGB_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_LGB_filtered.columns = [column.split('.')[-1] for column in df_LGB_filtered.columns]
#subset of dataframe
df1_LGB = df_LGB_filtered[['name','city', 'distance','lat','lng']]
df1_LGB
# Out:
# 33.8172681 -118.1418025
# Hilton Hotels .... OK!
#                                                 name          city  distance  \
# 0     DoubleTree Suites by Hilton Hotel Santa Monica  Santa Monica     38705
# 1  DoubleTree by Hilton Hotel San Pedro - Port of...     San Pedro     17018
# 2                                 Hilton Hotels Corp   California,     36987
# 3  DoubleTree by Hilton Hotel Santa Ana - Orange ...     Santa Ana     28632
# 4       Hilton Long Beach & Executive Meeting Center    Long Beach      7765
# 5                                     Hilton Anaheim       Anaheim     20742
# 6       Homewood Suites by Hilton Long Beach Airport    Long Beach      1115
# 7          Hotel Maya - a DoubleTree by Hilton Hotel    Long Beach      8544
# 8                         Hilton Los Angeles Airport   Los Angeles     26402
# 9                            Hilton Hotel Pool & Spa       Anaheim     20751
#
#          lat         lng
# 0  34.011744 -118.489113
# 1  33.718573 -118.282252
# 2  34.076288 -118.392676
# 3  33.700441 -117.866176
# 4  33.768026 -118.201263
# 5  33.800684 -117.918432
# 6  33.827158 -118.143755
# 7  33.756790 -118.198665
# 8  33.946177 -118.381616
# 9  33.800965 -117.918306

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around LGB
# add a red circle marker to represent LGB
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Hilton Hotels as blue circle markers
for lat, lng, label in zip(df_LGB_filtered.lat, df_LGB_filtered.lng, df_LGB_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Searching for attractions near ONT
address = '2500 E Airport Dr. Ontario, CA 91761'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

search_query = 'Hilton Hotels'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_ONT = json_normalize(venues)
df_ONT.head()
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_ONT.columns if col.startswith('location.')] + ['id']
df_ONT_filtered = df_ONT.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_ONT_filtered['categories'] = df_ONT_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_ONT_filtered.columns = [column.split('.')[-1] for column in df_ONT_filtered.columns]
#subset of dataframe
df1_ONT = df_ONT_filtered[['name','city', 'distance','lat','lng']]
df1_ONT
# Out:
# 34.062531 -117.600645
# Hilton Hotels .... OK!
#                                                 name              city  \
# 0     DoubleTree Suites by Hilton Hotel Santa Monica      Santa Monica
# 1  DoubleTree by Hilton Hotel Santa Ana - Orange ...         Santa Ana
# 2         DoubleTree by Hilton Hotel Ontario Airport           Ontario
# 3                                 Hilton Hotels Corp       California,
# 4          DoubleTree by Hilton Hotel San Bernardino    San Bernardino
# 5                                  Hilton Garden Inn  Rancho Cucamonga
# 6  DoubleTree by Hilton Hotel San Pedro - Port of...         San Pedro
# 7              Poolside Ontario Doubletree By Hilton           Ontario
# 8           Embassy Suites by Hilton Ontario Airport           Ontario
# 9               DoubleTree by Hilton Hotel Claremont         Claremont
#
#    distance        lat         lng
# 0     82153  34.011744 -118.489113
# 1     47189  33.700441 -117.866176
# 2       942  34.066027 -117.609952
# 3     73050  34.076288 -118.392676
# 4     29509  34.065231 -117.280670
# 5      4637  34.078965 -117.554427
# 6     73709  33.718573 -118.282252
# 7       893  34.065760 -117.609518
# 8      2585  34.065463 -117.572827
# 9     12423  34.107590 -117.723924

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around ONT

# add a red circle marker to represent ONT
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Hilton Hotels as blue circle markers
for lat, lng, label in zip(df_SNA_filtered.lat, df_ONT_filtered.lng, df_ONT_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Searching for attractions near SAN
address = '3225 N Harbor Dr San Diego, CA 92101'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

search_query = 'Hilton Hotels'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_SAN = json_normalize(venues)
df_SAN.head()
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_SAN.columns if col.startswith('location.')] + ['id']
df_SAN_filtered = df_SAN.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_SAN_filtered['categories'] = df_SAN_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_SAN_filtered.columns = [column.split('.')[-1] for column in df_SAN_filtered.columns]
#subset of dataframe
df1_SAN = df_SAN_filtered[['name','city', 'distance','lat','lng']]
df1_SAN
# Out:
# 32.7292147341561 -117.190403029551
# Hilton Hotels .... OK!
#                                                 name       city  distance  \
# 0      DoubleTree by Hilton Hotel San Diego Downtown  San Diego      2480
# 1  DoubleTree by Hilton Hotel San Diego - Hotel C...  San Diego      3499
# 2  DoubleTree by Hilton Hotel San Diego - Mission...  San Diego      5351
# 3     DoubleTree by Hilton Hotel San Diego - Del Mar  San Diego     23388
# 4                          Hilton San Diego Bayfront  San Diego      4146
# 5     Hilton Garden Inn - San Diego Downtown/Bayside  San Diego      1780
# 6             Hilton San Diego Airport/Harbor Island  San Diego      1803
# 7                    Hilton San Diego Mission Valley  San Diego      4988
# 8                   Hilton San Diego Gaslamp Quarter  San Diego      3641
# 9  Hilton Garden Inn San Diego Old Town/SeaWorld ...  San Diego      3319
#
#          lat         lng
# 0  32.722373 -117.165196
# 1  32.758521 -117.176870
# 2  32.770011 -117.160175
# 3  32.935730 -117.236432
# 4  32.703370 -117.158518
# 5  32.726250 -117.171720
# 6  32.725182 -117.209054
# 7  32.763896 -117.156665
# 8  32.708026 -117.160777
# 9  32.758340 -117.198000

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around SAN

# add a red circle marker to represent SAN
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Hilton Hotels as blue circle markers
for lat, lng, label in zip(df_SAN_filtered.lat, df_SAN_filtered.lng, df_SAN_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### K-means Clustering

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

print('Libraries imported.')
